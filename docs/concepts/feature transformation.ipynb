# %% [markdown]
# ## KGFarm's feature transformation

# %%
import sys
import pandas as pd
sys.path.append('../../')

from operations.api import KGFarm
kgfarm = KGFarm()
# Out:
# Connected to Stardog!
# Access the Stardog UI at: https://cloud.stardog.com/

# %% [markdown]
# KGFarm exploits the abstracted link between the KGLiDS graph and Farm graph
#    * <code> kgfarm.recommend_feature_transformations</code> returns all possible set of feature transformations that exists in the database.
#    * <b> You can pass your existing <code>entity_df</code> to <code>kgfarm.recommend_feature_transformations(entity:pd.Dataframe)</code> to look for possible feature transformations for that very entity dataframe.

# %%
transformation_info = kgfarm.recommend_feature_transformations()
transformation_info
# Out:
#    Transformation        Package                         Function  Library  \
# 0    LabelEncoder  preprocessing    LabelEncoder.fit_transform( )  sklearn
# 1    MinMaxScaler  preprocessing    MinMaxScaler.fit_transform( )  sklearn
# 2    MinMaxScaler  preprocessing    MinMaxScaler.fit_transform( )  sklearn
# 3  StandardScaler  preprocessing  StandardScaler.fit_transform( )  sklearn
# 4  StandardScaler  preprocessing  StandardScaler.fit_transform( )  sklearn
# 5    LabelEncoder  preprocessing    LabelEncoder.fit_transform( )  sklearn
# 6    LabelEncoder  preprocessing    LabelEncoder.fit_transform( )  sklearn
#
#                                                                  Feature  \
# 0  [Tenure, IsActiveMember, NumOfProducts, HasCrCard, Gender, Geography]
# 1                                                          [CreditScore]
# 2                                                          [CreditScore]
# 3                                                          [CreditScore]
# 4                                     [Balance, Tenure, EstimatedSalary]
# 5              [month, job, contact, education, marital, poutcome, loan]
# 6                                                    [Geography, Gender]
#
#       Feature_view                Table                       Dataset  \
# 0  Feature_view_10  Churn_Modelling.csv  bank-customer-churn-modeling
# 1  Feature_view_10  Churn_Modelling.csv  bank-customer-churn-modeling
# 2  Feature_view_10  Churn_Modelling.csv  bank-customer-churn-modeling
# 3  Feature_view_10  Churn_Modelling.csv  bank-customer-churn-modeling
# 4  Feature_view_10  Churn_Modelling.csv  bank-customer-churn-modeling
# 5  Feature_view_06             bank.csv        bank-marketing-dataset
# 6  Feature_view_09            churn.csv      churn-for-bank-customers
#
#               Author           Written_on  \
# 0    Ryan M Cummings  2020-07-19 18:47:46
# 1      Karthik Stock  2021-09-07 11:03:28
# 2    Namanjeet Singh  2021-03-11 13:06:33
# 3    Ryan M Cummings  2020-07-19 18:47:46
# 4         fei yutong  2021-10-28 22:31:54
# 5  Nishigandha.Zanje  2022-01-02 10:33:50
# 6       AYAHM BARISH  2021-11-17 17:05:01
#
#                                           Pipeline  \
# 0    Customer Churn Rate - Machine Learning Models
# 1                customer exited or not prediction
# 2  NeuralNetworks with Regularization and Sampling
# 3    Customer Churn Rate - Machine Learning Models
# 4                     Bank customer churn modeling
# 5      SL_BankMarketing_TermDeposit_Classification
# 6    CatBoost Classifier ve DecisionTreeClassifier
#
#                                                                             Pipeline_url
# 0       https://www.kaggle.com/ryanmcummings/customer-churn-rate-machine-learning-models
# 1                  https://www.kaggle.com/karthikstock/customer-exited-or-not-prediction
# 2  https://www.kaggle.com/namanjeetsingh/neuralnetworks-with-regularization-and-sampling
# 3       https://www.kaggle.com/ryanmcummings/customer-churn-rate-machine-learning-models
# 4                          https://www.kaggle.com/feiyutong/bank-customer-churn-modeling
# 5    https://www.kaggle.com/nishigandhazanje/sl-bankmarketing-termdeposit-classification
# 6          https://www.kaggle.com/ayhampar/catboost-classifier-ve-decisiontreeclassifier

# %%
option = 0 # row in transformation_info
entity_df = kgfarm.load_table(transformation_info.iloc[option])
entity_df
# Out:
# Churn_Modelling.csv
#       RowNumber  CustomerId        Surname  CreditScore Geography  Gender  \
# 0          3026    15745232        Chikelu          759    France  Female
# 1          2356    15710366       Hamilton          569     Spain  Female
# 2          6895    15707441          White          690     Spain    Male
# 3          1804    15707078        Kruglov          577    France  Female
# 4          4192    15715597  Onyemauchechi          679    France    Male
# ...         ...         ...            ...          ...       ...     ...
# 9995       5207    15632826        Tardent          493    France    Male
# 9996        938    15662100            Hsu          850   Germany  Female
# 9997       2671    15760446       Pagnotto          598    France  Female
# 9998       5516    15742534          Faulk          527   Germany  Female
# 9999       8866    15639004      Chiemezie          668    France    Male
#
#       Age  Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0      39       6       0.00              2          1               1
# 1      42       1       0.00              1          1               1
# 2      26       8  116318.23              1          1               1
# 3      26       1  180530.51              1          0               0
# 4      36       1   97234.58              1          1               0
# ...   ...     ...        ...            ...        ...             ...
# 9995   38       3  134006.77              1          1               0
# 9996   44       5  128605.32              1          0               1
# 9997   64       9       0.00              1          0               1
# 9998   28       2  123802.98              2          1               1
# 9999   72       2       0.00              2          1               1
#
#       EstimatedSalary  Exited             event_timestamp
# 0           140497.67       0  2022-07-25 00:00:03.619623
# 1            83629.60       1  2022-07-25 00:01:45.619623
# 2            83253.05       0  2022-07-25 00:04:53.619623
# 3           123454.62       0  2022-07-25 00:05:44.619623
# 4           188997.08       0  2022-07-25 00:05:48.619623
# ...               ...     ...                         ...
# 9995         89578.32       0  2022-08-03 23:51:49.619623
# 9996        171096.20       0  2022-08-03 23:52:30.619623
# 9997         13181.37       1  2022-08-03 23:54:19.619623
# 9998        155846.69       0  2022-08-03 23:54:34.619623
# 9999         70783.61       0  2022-08-03 23:55:46.619623
#
# [10000 rows x 15 columns]

# %%
kgfarm.apply_transformation(transformation_info.iloc[option])
# Out:
# Applying LabelEncoder transformation
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 497.31it/s]
# 6 feature(s) ['Tenure', 'IsActiveMember', 'NumOfProducts', 'HasCrCard', 'Gender', 'Geography'] transformed successfully!
#       RowNumber  CustomerId        Surname  CreditScore  Geography  Gender  \
# 0          3026    15745232        Chikelu          759          0       0
# 1          2356    15710366       Hamilton          569          2       0
# 2          6895    15707441          White          690          2       1
# 3          1804    15707078        Kruglov          577          0       0
# 4          4192    15715597  Onyemauchechi          679          0       1
# ...         ...         ...            ...          ...        ...     ...
# 9995       5207    15632826        Tardent          493          0       1
# 9996        938    15662100            Hsu          850          1       0
# 9997       2671    15760446       Pagnotto          598          0       0
# 9998       5516    15742534          Faulk          527          1       0
# 9999       8866    15639004      Chiemezie          668          0       1
#
#       Age  Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0      39       6       0.00              1          1               1
# 1      42       1       0.00              0          1               1
# 2      26       8  116318.23              0          1               1
# 3      26       1  180530.51              0          0               0
# 4      36       1   97234.58              0          1               0
# ...   ...     ...        ...            ...        ...             ...
# 9995   38       3  134006.77              0          1               0
# 9996   44       5  128605.32              0          0               1
# 9997   64       9       0.00              0          0               1
# 9998   28       2  123802.98              1          1               1
# 9999   72       2       0.00              1          1               1
#
#       EstimatedSalary  Exited             event_timestamp
# 0           140497.67       0  2022-07-25 00:00:03.619623
# 1            83629.60       1  2022-07-25 00:01:45.619623
# 2            83253.05       0  2022-07-25 00:04:53.619623
# 3           123454.62       0  2022-07-25 00:05:44.619623
# 4           188997.08       0  2022-07-25 00:05:48.619623
# ...               ...     ...                         ...
# 9995         89578.32       0  2022-08-03 23:51:49.619623
# 9996        171096.20       0  2022-08-03 23:52:30.619623
# 9997         13181.37       1  2022-08-03 23:54:19.619623
# 9998        155846.69       0  2022-08-03 23:54:34.619623
# 9999         70783.61       0  2022-08-03 23:55:46.619623
#
# [10000 rows x 15 columns]
