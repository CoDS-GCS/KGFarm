# %% [markdown]
# ## KGFarm's feature transformation

# %%
import sys
import pandas as pd
sys.path.append('../../')

from operations.api import KGFarm
kgfarm = KGFarm()
# Out:
# (Running in HITL (Human in the loop) mode)
# Connected to Stardog!
# Access the Stardog UI at: https://cloud.stardog.com/

# %% [markdown]
# KGFarm exploits the abstracted link between the KGLiDS graph and Farm graph
#    * <code> kgfarm.recommend_feature_transformations</code> returns all possible set of feature transformations that exists in the database.
#    * <b> You can pass your existing <code>entity_df</code> to <code>kgfarm.recommend_feature_transformations(entity:pd.Dataframe)</code> to look for possible feature transformations for that very entity dataframe.

# %%
transformation_info = kgfarm.recommend_feature_transformations()
transformation_info
# Out:
#    Transformation        Package                         Function  Library  \
# 0    LabelEncoder  preprocessing    LabelEncoder.fit_transform( )  sklearn
# 1    MinMaxScaler  preprocessing    MinMaxScaler.fit_transform( )  sklearn
# 2    MinMaxScaler  preprocessing    MinMaxScaler.fit_transform( )  sklearn
# 3  StandardScaler  preprocessing  StandardScaler.fit_transform( )  sklearn
# 4  StandardScaler  preprocessing  StandardScaler.fit_transform( )  sklearn
# 5    LabelEncoder  preprocessing    LabelEncoder.fit_transform( )  sklearn
# 6    LabelEncoder  preprocessing    LabelEncoder.fit_transform( )  sklearn
# 7    LabelEncoder  preprocessing    LabelEncoder.fit_transform( )  sklearn
# 8  StandardScaler  preprocessing  StandardScaler.fit_transform( )  sklearn
#
#                                                                  Feature  \
# 0  [Tenure, IsActiveMember, NumOfProducts, HasCrCard, Gender, Geography]
# 1                                                          [CreditScore]
# 2                                                          [CreditScore]
# 3                                                          [CreditScore]
# 4                                     [EstimatedSalary, Tenure, Balance]
# 5              [loan, education, contact, marital, job, month, poutcome]
# 6                                                           [membership]
# 7                                                    [Geography, Gender]
# 8                                        [Age, EstimatedSalary, Balance]
#
#       Feature_view                Table                       Dataset  \
# 0  Feature_view_08  Churn_Modelling.csv  bank-customer-churn-modeling
# 1  Feature_view_08  Churn_Modelling.csv  bank-customer-churn-modeling
# 2  Feature_view_08  Churn_Modelling.csv  bank-customer-churn-modeling
# 3  Feature_view_08  Churn_Modelling.csv  bank-customer-churn-modeling
# 4  Feature_view_08  Churn_Modelling.csv  bank-customer-churn-modeling
# 5  Feature_view_02             bank.csv        bank-marketing-dataset
# 6  Feature_view_03       bank_stats.csv        bank-marketing-dataset
# 7  Feature_view_09            churn.csv      churn-for-bank-customers
# 8  Feature_view_09            churn.csv      churn-for-bank-customers
#
#               Author           Written_on  \
# 0    Ryan M Cummings  2020-07-19 18:47:46
# 1      Karthik Stock  2021-09-07 11:03:28
# 2    Namanjeet Singh  2021-03-11 13:06:33
# 3    Ryan M Cummings  2020-07-19 18:47:46
# 4         fei yutong  2021-10-28 22:31:54
# 5  Nishigandha.Zanje  2022-01-02 10:33:50
# 6   Shubham Vashisth  2022-08-23 14:44:25
# 7       AYAHM BARISH  2021-11-17 17:05:01
# 8       AYAHM BARISH  2021-11-17 17:05:01
#
#                                           Pipeline  \
# 0    Customer Churn Rate - Machine Learning Models
# 1                customer exited or not prediction
# 2  NeuralNetworks with Regularization and Sampling
# 3    Customer Churn Rate - Machine Learning Models
# 4                     Bank customer churn modeling
# 5      SL_BankMarketing_TermDeposit_Classification
# 6                              Bank stats analysis
# 7    CatBoost Classifier ve DecisionTreeClassifier
# 8    CatBoost Classifier ve DecisionTreeClassifier
#
#                                                                             Pipeline_url
# 0       https://www.kaggle.com/ryanmcummings/customer-churn-rate-machine-learning-models
# 1                  https://www.kaggle.com/karthikstock/customer-exited-or-not-prediction
# 2  https://www.kaggle.com/namanjeetsingh/neuralnetworks-with-regularization-and-sampling
# 3       https://www.kaggle.com/ryanmcummings/customer-churn-rate-machine-learning-models
# 4                          https://www.kaggle.com/feiyutong/bank-customer-churn-modeling
# 5    https://www.kaggle.com/nishigandhazanje/sl-bankmarketing-termdeposit-classification
# 6                                                       https:shubhamvashisth7.github.io
# 7          https://www.kaggle.com/ayhampar/catboost-classifier-ve-decisiontreeclassifier
# 8          https://www.kaggle.com/ayhampar/catboost-classifier-ve-decisiontreeclassifier

# %%
option = 0 # row in transformation_info
entity_df = kgfarm.load_table(transformation_info.iloc[option])
entity_df
# Out:
# Churn_Modelling.csv
#                  event_timestamp  RowNumber  CustomerId     Surname  \
# 0     2022-08-17 00:00:08.642218       3419    15632272        Lung
# 1     2022-08-17 00:03:32.642218       5347    15688644    Holloway
# 2     2022-08-17 00:08:49.642218       2545    15709487     Freeman
# 3     2022-08-17 00:12:34.642218       8870    15733597        Y?an
# 4     2022-08-17 00:13:39.642218       2604    15583049     Wallace
# ...                          ...        ...         ...         ...
# 9995  2022-08-25 23:53:01.642218       8591    15633194     Osborne
# 9996  2022-08-25 23:53:16.642218       2813    15581620    Franklin
# 9997  2022-08-25 23:54:45.642218       9991    15798964  Nkemakonam
# 9998  2022-08-25 23:58:00.642218       1024    15682639    Marshall
# 9999  2022-08-25 23:59:35.642218       6785    15570912   Ogbonnaya
#
#       CreditScore Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             792    France  Female   42       2       0.00              2
# 1             603    France    Male   31       1  129743.75              1
# 2             668   Germany    Male   34       5   80242.37              2
# 3             669    France  Female   41       0  150219.41              2
# 4             643   Germany  Female   34       7  160426.07              1
# ...           ...       ...     ...  ...     ...        ...            ...
# 9995          771    France  Female   41      10  108309.00              4
# 9996          597    France    Male   28       2       0.00              3
# 9997          714   Germany    Male   33       3   35016.60              1
# 9998          642    France    Male   32       3       0.00              2
# 9999          728   Germany  Female   32       9  127772.10              2
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0             1               0         92664.09       0
# 1             1               0        109145.20       0
# 2             0               0         56780.97       0
# 3             0               0        107839.03       0
# 4             0               1        188533.11       0
# ...         ...             ...              ...     ...
# 9995          1               1        137510.41       1
# 9996          1               1         78707.97       0
# 9997          1               0         53667.08       0
# 9998          1               1         88698.83       0
# 9999          1               1        152643.48       0
#
# [10000 rows x 15 columns]

# %%
kgfarm.apply_transformation(transformation_info.iloc[option])
# Out:
# 100%|██████████████████████████████████████████████████████████████████████████| 6/6 [00:00<00:00, 613.43it/s]
# Applying LabelEncoder transformation
# 6 feature(s) ['Tenure', 'IsActiveMember', 'NumOfProducts', 'HasCrCard', 'Gender', 'Geography'] transformed successfully!
#                  event_timestamp  RowNumber  CustomerId     Surname  \
# 0     2022-08-17 00:00:08.642218       3419    15632272        Lung
# 1     2022-08-17 00:03:32.642218       5347    15688644    Holloway
# 2     2022-08-17 00:08:49.642218       2545    15709487     Freeman
# 3     2022-08-17 00:12:34.642218       8870    15733597        Y?an
# 4     2022-08-17 00:13:39.642218       2604    15583049     Wallace
# ...                          ...        ...         ...         ...
# 9995  2022-08-25 23:53:01.642218       8591    15633194     Osborne
# 9996  2022-08-25 23:53:16.642218       2813    15581620    Franklin
# 9997  2022-08-25 23:54:45.642218       9991    15798964  Nkemakonam
# 9998  2022-08-25 23:58:00.642218       1024    15682639    Marshall
# 9999  2022-08-25 23:59:35.642218       6785    15570912   Ogbonnaya
#
#       CreditScore  Geography  Gender  Age  Tenure    Balance  NumOfProducts  \
# 0             792          0       0   42       2       0.00              1
# 1             603          0       1   31       1  129743.75              0
# 2             668          1       1   34       5   80242.37              1
# 3             669          0       0   41       0  150219.41              1
# 4             643          1       0   34       7  160426.07              0
# ...           ...        ...     ...  ...     ...        ...            ...
# 9995          771          0       0   41      10  108309.00              3
# 9996          597          0       1   28       2       0.00              2
# 9997          714          1       1   33       3   35016.60              0
# 9998          642          0       1   32       3       0.00              1
# 9999          728          1       0   32       9  127772.10              1
#
#       HasCrCard  IsActiveMember  EstimatedSalary  Exited
# 0             1               0         92664.09       0
# 1             1               0        109145.20       0
# 2             0               0         56780.97       0
# 3             0               0        107839.03       0
# 4             0               1        188533.11       0
# ...         ...             ...              ...     ...
# 9995          1               1        137510.41       1
# 9996          1               1         78707.97       0
# 9997          1               0         53667.08       0
# 9998          1               1         88698.83       0
# 9999          1               1        152643.48       0
#
# [10000 rows x 15 columns]
