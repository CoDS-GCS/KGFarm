# %% [markdown]
# # KGFarm's feature cleaning

# %%
import os
import pandas as pd
os.chdir('../../')

from operations.api import KGFarm
kgfarm = KGFarm()
# Out:
# (KGFarm is running in Human in the loop mode)
# Connected to Stardog!
# Access the Stardog UI at: https://cloud.stardog.com/

# %%
entity_df = pd.read_csv('/Users/shubhamvashisth/Downloads/KGFarm_material/transformation/train (1).csv')
entity_df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
cleaning_info = kgfarm.recommend_cleaning_operations(entity_df, show_query=False)
cleaning_info
# Out:
# scanning missing values
# finding similar columns and tables to entity dataframe
# 100%|██████████| 8/8 [00:14<00:00,  1.78s/it]
#              Operation  \
# 0  Fill missing values
# 1  Fill missing values
# 2  Fill missing values
# 3  Fill missing values
# 4  Fill missing values
# 5  Fill missing values
# 6  Fill missing values
# 7  Fill missing values
#
#                                                                                                                                                                                                                                                                                                       Feature  \
# 0                                                                                                                                                                                                                                                                                    [MasVnrType, MasVnrArea]
# ...

# %%
entity_df = kgfarm.clean(entity_df, cleaning_info.iloc[4])
entity_df
# Out:
# filled missing values for ['Fence', 'GarageQual', 'GarageType', 'PoolQC', 'MiscFeature', 'GarageFinish', 'BsmtFullBath', 'TotalBsmtSF', 'BsmtHalfBath', 'BsmtFinSF1', 'BsmtUnfSF', 'BsmtFinSF2', 'LotFrontage', 'GarageCond', 'MasVnrArea', 'FireplaceQu', 'GarageCars', 'Alley', 'GarageArea', 'BsmtFinType1', 'BsmtCond', 'BsmtQual', 'GarageYrBlt', 'BsmtExposure', 'BsmtFinType2'] feature(s)
#
# ['MasVnrType', 'Neighborhood', 'Electrical'] are still uncleaned
#         Id  MSSubClass MSZoning LotFrontage  LotArea Street     Alley  \
# 0        1          60       RL        65.0     8450   Pave  No Alley
# 1        2          20       RL        80.0     9600   Pave  No Alley
# 2        3          60       RL        68.0    11250   Pave  No Alley
# 3        4          70       RL        60.0     9550   Pave  No Alley
# 4        5          60       RL        84.0    14260   Pave  No Alley
# ...    ...         ...      ...         ...      ...    ...       ...
# ...

# %%
entity_df = kgfarm.clean(entity_df, technique='fill')
entity_df
# Out:
# Enter the value to fill the missing data or 'mean', 'median', 'mode' to fill by statisticsmode
# 100%|██████████| 3/3 [00:00<00:00, 495.80it/s]
# missing values from ['MasVnrType', 'Neighborhood', 'Electrical'] were filled with mode
#
# all features look clean
#         Id  MSSubClass MSZoning LotFrontage  LotArea Street     Alley  \
# 0        1          60       RL        65.0     8450   Pave  No Alley
# 1        2          20       RL        80.0     9600   Pave  No Alley
# 2        3          60       RL        68.0    11250   Pave  No Alley
# 3        4          70       RL        60.0     9550   Pave  No Alley
# 4        5          60       RL        84.0    14260   Pave  No Alley
# ...    ...         ...      ...         ...      ...    ...       ...
# 1455  1456          60       RL        62.0     7917   Pave  No Alley
# 1456  1457          20       RL        85.0    13175   Pave  No Alley
# 1457  1458          70       RL        66.0     9042   Pave  No Alley
# ...

# %%
entity_df = pd.read_csv('/Users/shubhamvashisth/Downloads/KGFarm_material/transformation/train.csv')
entity_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                     Name     Sex   Age  SibSp  \
# 0                                Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                                 Heikkinen, Miss. Laina  female  26.0      0
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                               Allen, Mr. William Henry    male  35.0      0
# ...

# %%
cleaning_info = kgfarm.recommend_cleaning_operations(entity_df)
cleaning_info
# Out:
# scanning missing values
# finding similar columns and tables to entity dataframe
# 100%|██████████| 4/4 [00:03<00:00,  1.15it/s]
#              Operation                 Feature  \
# 0  Fill missing values                   [Age]
# 1  Fill missing values  [Cabin, Age, Embarked]
# 2  Fill missing values              [Embarked]
# 3  Fill missing values                 [Cabin]
# 4  Drop missing values                   [Age]
# 5  Fill missing values                   [Age]
#
#                                                                          Parameters  \
# 0                                 {'Age': '<src.Calls.Call object at 0x1176160a0>'}
# 1  {'Cabin': '0', 'Age': '<src.Calls.Call object at 0x1231b76d0>', 'Embarked': '0'}
# 2                                                             {'Embarked': 'bfill'}
# 3                                                                    {'Cabin': 'U'}
# 4                                                                    {'Age': 'any'}
# ...

# %%
entity_df = kgfarm.clean(entity_df, cleaning_info.iloc[4])
entity_df
# Out:
# dropped missing values for ['Age'] feature(s)
#
# ['Cabin', 'Name', 'Embarked'] are still uncleaned
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                     Name     Sex   Age  SibSp  \
# 0                                Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 2                                                    NaN  female  26.0      0
# 3           Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# ...

# %%
entity_df = kgfarm.clean(entity_df, technique='drop')
entity_df
# Out:
# missing values from ['Cabin', 'Name', 'Embarked'] were dropped
#
# all features look clean
#      PassengerId  Survived  Pclass  \
# 0              2         1       1
# 1              4         1       1
# 2              7         0       1
# 3             11         1       3
# 4             12         1       1
# ..           ...       ...     ...
# 159          868         0       1
# 160          873         0       1
# 161          880         1       1
# 162          888         1       1
# 163          890         1       1
#
#                                                     Name     Sex   Age  SibSp  \
# 0    Cumings, Mrs. John Bradley (Florence Briggs Thayer)  female  38.0      1
# 1           Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 2                                McCarthy, Mr. Timothy J    male  54.0      0
# 3                        Sandstrom, Miss. Marguerite Rut  female   4.0      1
# ...

# %%
entity_df = pd.read_csv('/Users/shubhamvashisth/Downloads/KGFarm_material/data_lake/bank-marketing-dataset/data/bank.csv')
entity_df
# Out:
#       customer_id          job  marital  education  housing loan   contact  \
# 0         C_07000       admin.  married  secondary        1   no   unknown
# 1         C_07001       admin.  married  secondary        0   no   unknown
# 2         C_07002   technician  married  secondary        1   no   unknown
# 3         C_07003     services  married  secondary        1   no   unknown
# 4         C_07004       admin.  married   tertiary        0   no   unknown
# ...           ...          ...      ...        ...      ...  ...       ...
# 11157     C_18157  blue-collar   single    primary        1   no  cellular
# 11158     C_18158     services  married  secondary        0   no   unknown
# 11159     C_18159   technician   single  secondary        0   no  cellular
# 11160     C_18160   technician  married  secondary        0  yes  cellular
# 11161     C_18161   technician  married  secondary        0   no  cellular
#
#       month poutcome
# 0       may  unknown
# 1       may  unknown
# ...

# %%
cleaning_info = kgfarm.recommend_cleaning_operations(entity_df)
cleaning_info
# Out:
# scanning missing values
#      Operation                Feature           Parameters       Pipeline
# 0  Interpolate  [job, month, contact]  {'method': 'ffill'}  data cleaning

# %%
entity_df = kgfarm.clean(entity_df, cleaning_info.iloc[0])
entity_df
# Out:
# interpolated missing values for ['job', 'month', 'contact'] feature(s)
#
# all features look clean
#       customer_id          job  marital  education  housing loan   contact  \
# 0         C_07000       admin.  married  secondary        1   no   unknown
# 1         C_07001       admin.  married  secondary        0   no   unknown
# 2         C_07002   technician  married  secondary        1   no   unknown
# 3         C_07003     services  married  secondary        1   no   unknown
# 4         C_07004       admin.  married   tertiary        0   no   unknown
# ...           ...          ...      ...        ...      ...  ...       ...
# 11157     C_18157  blue-collar   single    primary        1   no  cellular
# 11158     C_18158     services  married  secondary        0   no   unknown
# 11159     C_18159   technician   single  secondary        0   no  cellular
# 11160     C_18160   technician  married  secondary        0  yes  cellular
# ...
