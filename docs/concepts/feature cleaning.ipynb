# %% [markdown]
# # KGFarm's feature cleaning

# %%
import os
import pandas as pd
os.chdir('../../')

from operations.api import KGFarm
kgfarm = KGFarm()
# Out:
# (KGFarm is running in Human in the loop mode)
# Connected to Stardog!
# Access the Stardog UI at: https://cloud.stardog.com/

# %%
entity_info = kgfarm.search_entity(entity_name='customer')
entity_info
# Out:
#                      Entity Physical_representation     Feature_view  \
# 0       customer_bank_stats             customer_id  Feature_view_03
# 1             customer_bank             customer_id  Feature_view_02
# 2            customer_churn              CustomerId  Feature_view_09
# 3  customer_Churn_Modelling              CustomerId  Feature_view_08
#
#         Physical_table  Number_of_rows  \
# 0       bank_stats.csv           12162
# 1             bank.csv           11162
# 2            churn.csv           10000
# 3  Churn_Modelling.csv           10000
#
#                                                                                              File_source
# 0             /Users/shubhamvashisth/Documents/data/data_lake/bank-marketing-dataset/data/bank_stats.csv
# 1                   /Users/shubhamvashisth/Documents/data/data_lake/bank-marketing-dataset/data/bank.csv
# 2                /Users/shubhamvashisth/Documents/data/data_lake/churn-for-bank-customers/data/churn.csv
# ...

# %%
option = 1  # row number in enrichment_info dataframe

entity_df = pd.read_csv(entity_info.iloc[option].File_source)
print('entity dataframe: ', entity_info.iloc[option].Physical_table)
entity_df
# Out:
# entity dataframe:  bank.csv
#                   event_timestamp customer_id           job   marital  \
# 0      2022-08-17 00:01:15.308550     C_07020        admin.  divorced
# 1      2022-08-17 00:03:02.308550     C_15150   blue-collar   married
# 2      2022-08-17 00:06:17.308550     C_13368        admin.   married
# 3      2022-08-17 00:06:23.308550     C_12883    management   married
# 4      2022-08-17 00:06:38.308550     C_17496   blue-collar   married
# ...                           ...         ...           ...       ...
# 11157  2022-08-25 23:48:36.308550     C_11774      services   married
# 11158  2022-08-25 23:52:51.308550     C_15935  entrepreneur   married
# 11159  2022-08-25 23:55:22.308550     C_10609        admin.   married
# 11160  2022-08-25 23:58:56.308550     C_13598   blue-collar    single
# 11161  2022-08-25 23:58:59.308550     C_16867       retired   married
#
#        education  housing loan   contact month poutcome
# ...

# %%
entity_df = kgfarm.clean_data(entity_df)
entity_df
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 16.57it/s]
# interpolated 3 features using 'pandas.DataFrame.interpolate' by method = 'ffill'
#                   event_timestamp customer_id           job   marital  \
# 0      2022-08-17 00:01:15.308550     C_07020        admin.  divorced
# 1      2022-08-17 00:03:02.308550     C_15150   blue-collar   married
# 2      2022-08-17 00:06:17.308550     C_13368        admin.   married
# 3      2022-08-17 00:06:23.308550     C_12883        admin.   married
# 4      2022-08-17 00:06:38.308550     C_17496   blue-collar   married
# ...                           ...         ...           ...       ...
# 11157  2022-08-25 23:48:36.308550     C_11774      services   married
# 11158  2022-08-25 23:52:51.308550     C_15935  entrepreneur   married
# 11159  2022-08-25 23:55:22.308550     C_10609        admin.   married
# ...

# %%
entity_df = pd.read_csv('/Users/shubhamvashisth/Downloads/KGFarm_material/transformation/train (1).csv')
entity_df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
entity_df = kgfarm.clean_data(entity_df, technique='interpolate')
entity_df
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 27.58it/s]
# missing values from ['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'MasVnrType', 'FireplaceQu', 'LotFrontage', 'Neighborhood', 'GarageType', 'GarageYrBlt', 'GarageFinish', 'GarageQual', 'GarageCond', 'BsmtExposure', 'BsmtFinType2', 'BsmtFinType1', 'BsmtCond', 'BsmtQual', 'MasVnrArea', 'Electrical'] were interpolated
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...

# %%
entity_df = kgfarm.clean_data(entity_df, technique='fill')
entity_df
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 27.08it/s]
# Enter the value to fill the missing data mode
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 17/17 [00:00<00:00, 867.65it/s]
# missing values from ['PoolQC', 'MiscFeature', 'Alley', 'Fence', 'MasVnrType', 'FireplaceQu', 'Neighborhood', 'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond', 'BsmtExposure', 'BsmtFinType2', 'BsmtQual', 'BsmtCond', 'BsmtFinType1', 'Electrical'] were filled with mode
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave  Grvl      Reg
# 1        2          20       RL         80.0     9600   Pave  Grvl      Reg
# 2        3          60       RL         68.0    11250   Pave  Grvl      IR1
# ...

# %%
entity_df = kgfarm.clean_data(entity_df, technique='fill')
entity_df
# Out:
# 100%|█████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 26.36it/s]
# nothing to clean
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave  Grvl      Reg
# 1        2          20       RL         80.0     9600   Pave  Grvl      Reg
# 2        3          60       RL         68.0    11250   Pave  Grvl      IR1
# 3        4          70       RL         60.0     9550   Pave  Grvl      IR1
# 4        5          60       RL         84.0    14260   Pave  Grvl      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave  Grvl      Reg
# 1456  1457          20       RL         85.0    13175   Pave  Grvl      Reg
# 1457  1458          70       RL         66.0     9042   Pave  Grvl      Reg
# ...
