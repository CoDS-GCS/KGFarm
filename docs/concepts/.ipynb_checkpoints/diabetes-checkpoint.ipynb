# %% [markdown]
# ## KGFarm's feature transformation

# %%
import pandas as pd
entity_df = pd.read_csv(r'C:\Users\niki_\Google Drive\GRAD SCHOOL\Papers\KGFarm-LFE\ionosphere.csv')

# %%
import os
import pandas as pd
os.chdir('../../')

from operations.api import KGFarm
kgfarm = KGFarm()
# Out:
# (KGFarm is running in Human in the loop mode)
# Connected to Stardog!
# Access the Stardog UI at: https://cloud.stardog.com/

# %%
kgfarm.recommend_cleaning_operations(entity_df)
# Out:
# scanning missing values
# nothing to clean
#       id  'a01'  'a02'    'a03'    'a04'    'a05'    'a06'    'a07'    'a08'  \
# 0      1      1      0  0.99539 -0.05889  0.85243  0.02306  0.83398 -0.37708
# 1      2      1      0  1.00000 -0.18829  0.93035 -0.36156 -0.10868 -0.93597
# 2      3      1      0  1.00000 -0.03365  1.00000  0.00485  1.00000 -0.12062
# 3      4      1      0  1.00000 -0.45161  1.00000  1.00000  0.71216 -1.00000
# 4      5      1      0  1.00000 -0.02401  0.94140  0.06531  0.92106 -0.23255
# ..   ...    ...    ...      ...      ...      ...      ...      ...      ...
# 346  347      1      0  0.83508  0.08298  0.73739 -0.14706  0.84349 -0.05567
# 347  348      1      0  0.95113  0.00419  0.95183 -0.02723  0.93438 -0.01920
# 348  349      1      0  0.94701 -0.00034  0.93207 -0.03227  0.95177 -0.03431
# 349  350      1      0  0.90608 -0.01657  0.98122 -0.01989  0.95691 -0.03646
# 350  351      1      0  0.84710  0.13533  0.73638 -0.06151  0.87873  0.08260
#
#        'a09'    'a10'    'a11'    'a12'    'a13'    'a14'    'a15'    'a16'  \
# 0    1.00000  0.03760  0.85243 -0.17755  0.59755 -0.44945  0.60536 -0.38223
# 1    1.00000 -0.04549  0.50874 -0.67743  0.34432 -0.69707 -0.51685 -0.97515
# 2    0.88965  0.01198  0.73082  0.05346  0.85443  0.00827  0.54591  0.00299
# 3    0.00000  0.00000  0.00000  0.00000  0.00000  0.00000 -1.00000  0.14516
# 4    0.77152 -0.16399  0.52798 -0.20275  0.56409 -0.00712  0.34395 -0.27457
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 346  0.90441 -0.04622  0.89391  0.13130  0.81197  0.06723  0.79307 -0.08929
# 347  0.94590  0.01606  0.96510  0.03281  0.94171  0.07330  0.94625 -0.01326
# 348  0.95584  0.02446  0.94124  0.01766  0.92595  0.04688  0.93954 -0.01461
# 349  0.85746  0.00110  0.89724 -0.03315  0.89061 -0.01436  0.90608 -0.04530
# 350  0.88928 -0.09139  0.78735  0.06678  0.80668 -0.00351  0.79262 -0.01054
#
#        'a17'    'a18'    'a19'    'a20'    'a21'    'a22'    'a23'    'a24'  \
# 0    0.84356 -0.38542  0.58212 -0.32192  0.56971 -0.29674  0.36946 -0.47357
# 1    0.05499 -0.62237  0.33109 -1.00000 -0.13151 -0.45300 -0.18056 -0.35734
# 2    0.83775 -0.13644  0.75535 -0.08540  0.70887 -0.27502  0.43385 -0.12062
# 3    0.54094 -0.39330 -1.00000 -0.54467 -0.69975  1.00000  0.00000  0.00000
# 4    0.52940 -0.21780  0.45107 -0.17813  0.05982 -0.35575  0.02309 -0.52879
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 346  1.00000 -0.02101  0.96639  0.06618  0.87605  0.01155  0.77521  0.06618
# 347  0.97173  0.00140  0.94834  0.06038  0.92670  0.08412  0.93124  0.10087
# 348  0.94837  0.02004  0.93784  0.01393  0.91406  0.07677  0.89470  0.06148
# 349  0.91381 -0.00884  0.80773 -0.12928  0.88729  0.01215  0.92155 -0.02320
# 350  0.85764 -0.04569  0.87170 -0.03515  0.81722 -0.09490  0.71002  0.04394
#
#        'a25'    'a26'    'a27'    'a28'    'a29'    'a30'    'a31'    'a32'  \
# 0    0.56811 -0.51171  0.41078 -0.46168  0.21266 -0.34090  0.42267 -0.54487
# 1   -0.20332 -0.26569 -0.20468 -0.18401 -0.19040 -0.11593 -0.16626 -0.06288
# 2    0.57528 -0.40220  0.58984 -0.22145  0.43100 -0.17365  0.60436 -0.24180
# 3    1.00000  0.90695  0.51613  1.00000  1.00000 -0.20099  0.25682  1.00000
# 4    0.03286 -0.65158  0.13290 -0.53206  0.02431 -0.62197 -0.05707 -0.59573
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 346  0.95378 -0.04202  0.83479  0.00123  1.00000  0.12815  0.86660 -0.10714
# 347  0.94520  0.01361  0.93522  0.04925  0.93159  0.08168  0.94066 -0.00035
# 348  0.93988  0.03193  0.92489  0.02542  0.92120  0.02242  0.92459  0.00442
# 349  0.91050 -0.02099  0.89147 -0.07760  0.82983 -0.17238  0.96022 -0.03757
# 350  0.86467 -0.15114  0.81147 -0.04822  0.78207 -0.00703  0.75747 -0.06678
#
#        'a33'    'a34' 'class'
# 0    0.18641 -0.45300       g
# 1   -0.13738 -0.02447       b
# 2    0.56045 -0.38238       g
# 3   -0.32382  1.00000       b
# 4   -0.04608 -0.65697       g
# ..       ...      ...     ...
# 346  0.90546 -0.04307       g
# 347  0.91483  0.04712       g
# 348  0.92697 -0.00577       g
# 349  0.87403 -0.16243       g
# 350  0.85764 -0.06151       g
#
# [351 rows x 36 columns]

# %%
entity_df
# Out:
#       id  'a01'  'a02'    'a03'    'a04'    'a05'    'a06'    'a07'    'a08'  \
# 0      1      1      0  0.99539 -0.05889  0.85243  0.02306  0.83398 -0.37708
# 1      2      1      0  1.00000 -0.18829  0.93035 -0.36156 -0.10868 -0.93597
# 2      3      1      0  1.00000 -0.03365  1.00000  0.00485  1.00000 -0.12062
# 3      4      1      0  1.00000 -0.45161  1.00000  1.00000  0.71216 -1.00000
# 4      5      1      0  1.00000 -0.02401  0.94140  0.06531  0.92106 -0.23255
# ..   ...    ...    ...      ...      ...      ...      ...      ...      ...
# 346  347      1      0  0.83508  0.08298  0.73739 -0.14706  0.84349 -0.05567
# 347  348      1      0  0.95113  0.00419  0.95183 -0.02723  0.93438 -0.01920
# 348  349      1      0  0.94701 -0.00034  0.93207 -0.03227  0.95177 -0.03431
# 349  350      1      0  0.90608 -0.01657  0.98122 -0.01989  0.95691 -0.03646
# 350  351      1      0  0.84710  0.13533  0.73638 -0.06151  0.87873  0.08260
#
#        'a09'    'a10'    'a11'    'a12'    'a13'    'a14'    'a15'    'a16'  \
# 0    1.00000  0.03760  0.85243 -0.17755  0.59755 -0.44945  0.60536 -0.38223
# 1    1.00000 -0.04549  0.50874 -0.67743  0.34432 -0.69707 -0.51685 -0.97515
# 2    0.88965  0.01198  0.73082  0.05346  0.85443  0.00827  0.54591  0.00299
# 3    0.00000  0.00000  0.00000  0.00000  0.00000  0.00000 -1.00000  0.14516
# 4    0.77152 -0.16399  0.52798 -0.20275  0.56409 -0.00712  0.34395 -0.27457
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 346  0.90441 -0.04622  0.89391  0.13130  0.81197  0.06723  0.79307 -0.08929
# 347  0.94590  0.01606  0.96510  0.03281  0.94171  0.07330  0.94625 -0.01326
# 348  0.95584  0.02446  0.94124  0.01766  0.92595  0.04688  0.93954 -0.01461
# 349  0.85746  0.00110  0.89724 -0.03315  0.89061 -0.01436  0.90608 -0.04530
# 350  0.88928 -0.09139  0.78735  0.06678  0.80668 -0.00351  0.79262 -0.01054
#
#        'a17'    'a18'    'a19'    'a20'    'a21'    'a22'    'a23'    'a24'  \
# 0    0.84356 -0.38542  0.58212 -0.32192  0.56971 -0.29674  0.36946 -0.47357
# 1    0.05499 -0.62237  0.33109 -1.00000 -0.13151 -0.45300 -0.18056 -0.35734
# 2    0.83775 -0.13644  0.75535 -0.08540  0.70887 -0.27502  0.43385 -0.12062
# 3    0.54094 -0.39330 -1.00000 -0.54467 -0.69975  1.00000  0.00000  0.00000
# 4    0.52940 -0.21780  0.45107 -0.17813  0.05982 -0.35575  0.02309 -0.52879
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 346  1.00000 -0.02101  0.96639  0.06618  0.87605  0.01155  0.77521  0.06618
# 347  0.97173  0.00140  0.94834  0.06038  0.92670  0.08412  0.93124  0.10087
# 348  0.94837  0.02004  0.93784  0.01393  0.91406  0.07677  0.89470  0.06148
# 349  0.91381 -0.00884  0.80773 -0.12928  0.88729  0.01215  0.92155 -0.02320
# 350  0.85764 -0.04569  0.87170 -0.03515  0.81722 -0.09490  0.71002  0.04394
#
#        'a25'    'a26'    'a27'    'a28'    'a29'    'a30'    'a31'    'a32'  \
# 0    0.56811 -0.51171  0.41078 -0.46168  0.21266 -0.34090  0.42267 -0.54487
# 1   -0.20332 -0.26569 -0.20468 -0.18401 -0.19040 -0.11593 -0.16626 -0.06288
# 2    0.57528 -0.40220  0.58984 -0.22145  0.43100 -0.17365  0.60436 -0.24180
# 3    1.00000  0.90695  0.51613  1.00000  1.00000 -0.20099  0.25682  1.00000
# 4    0.03286 -0.65158  0.13290 -0.53206  0.02431 -0.62197 -0.05707 -0.59573
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 346  0.95378 -0.04202  0.83479  0.00123  1.00000  0.12815  0.86660 -0.10714
# 347  0.94520  0.01361  0.93522  0.04925  0.93159  0.08168  0.94066 -0.00035
# 348  0.93988  0.03193  0.92489  0.02542  0.92120  0.02242  0.92459  0.00442
# 349  0.91050 -0.02099  0.89147 -0.07760  0.82983 -0.17238  0.96022 -0.03757
# 350  0.86467 -0.15114  0.81147 -0.04822  0.78207 -0.00703  0.75747 -0.06678
#
#        'a33'    'a34' 'class'
# 0    0.18641 -0.45300       g
# 1   -0.13738 -0.02447       b
# 2    0.56045 -0.38238       g
# 3   -0.32382  1.00000       b
# 4   -0.04608 -0.65697       g
# ..       ...      ...     ...
# 346  0.90546 -0.04307       g
# 347  0.91483  0.04712       g
# 348  0.92697 -0.00577       g
# 349  0.87403 -0.16243       g
# 350  0.85764 -0.06151       g
#
# [351 rows x 36 columns]

# %%
entity_df["'class'"] = entity_df["'class'"].apply(lambda x: 1 if x == 'b' else 0)
entity_df.reset_index(drop=True, inplace=True)
entity_df
# Out:
#       id  'a01'  'a02'    'a03'    'a04'    'a05'    'a06'    'a07'    'a08'  \
# 0      1      1      0  0.99539 -0.05889  0.85243  0.02306  0.83398 -0.37708
# 1      2      1      0  1.00000 -0.18829  0.93035 -0.36156 -0.10868 -0.93597
# 2      3      1      0  1.00000 -0.03365  1.00000  0.00485  1.00000 -0.12062
# 3      4      1      0  1.00000 -0.45161  1.00000  1.00000  0.71216 -1.00000
# 4      5      1      0  1.00000 -0.02401  0.94140  0.06531  0.92106 -0.23255
# ..   ...    ...    ...      ...      ...      ...      ...      ...      ...
# 346  347      1      0  0.83508  0.08298  0.73739 -0.14706  0.84349 -0.05567
# 347  348      1      0  0.95113  0.00419  0.95183 -0.02723  0.93438 -0.01920
# 348  349      1      0  0.94701 -0.00034  0.93207 -0.03227  0.95177 -0.03431
# 349  350      1      0  0.90608 -0.01657  0.98122 -0.01989  0.95691 -0.03646
# 350  351      1      0  0.84710  0.13533  0.73638 -0.06151  0.87873  0.08260
#
#        'a09'    'a10'    'a11'    'a12'    'a13'    'a14'    'a15'    'a16'  \
# 0    1.00000  0.03760  0.85243 -0.17755  0.59755 -0.44945  0.60536 -0.38223
# 1    1.00000 -0.04549  0.50874 -0.67743  0.34432 -0.69707 -0.51685 -0.97515
# 2    0.88965  0.01198  0.73082  0.05346  0.85443  0.00827  0.54591  0.00299
# 3    0.00000  0.00000  0.00000  0.00000  0.00000  0.00000 -1.00000  0.14516
# 4    0.77152 -0.16399  0.52798 -0.20275  0.56409 -0.00712  0.34395 -0.27457
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 346  0.90441 -0.04622  0.89391  0.13130  0.81197  0.06723  0.79307 -0.08929
# 347  0.94590  0.01606  0.96510  0.03281  0.94171  0.07330  0.94625 -0.01326
# 348  0.95584  0.02446  0.94124  0.01766  0.92595  0.04688  0.93954 -0.01461
# 349  0.85746  0.00110  0.89724 -0.03315  0.89061 -0.01436  0.90608 -0.04530
# 350  0.88928 -0.09139  0.78735  0.06678  0.80668 -0.00351  0.79262 -0.01054
#
#        'a17'    'a18'    'a19'    'a20'    'a21'    'a22'    'a23'    'a24'  \
# 0    0.84356 -0.38542  0.58212 -0.32192  0.56971 -0.29674  0.36946 -0.47357
# 1    0.05499 -0.62237  0.33109 -1.00000 -0.13151 -0.45300 -0.18056 -0.35734
# 2    0.83775 -0.13644  0.75535 -0.08540  0.70887 -0.27502  0.43385 -0.12062
# 3    0.54094 -0.39330 -1.00000 -0.54467 -0.69975  1.00000  0.00000  0.00000
# 4    0.52940 -0.21780  0.45107 -0.17813  0.05982 -0.35575  0.02309 -0.52879
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 346  1.00000 -0.02101  0.96639  0.06618  0.87605  0.01155  0.77521  0.06618
# 347  0.97173  0.00140  0.94834  0.06038  0.92670  0.08412  0.93124  0.10087
# 348  0.94837  0.02004  0.93784  0.01393  0.91406  0.07677  0.89470  0.06148
# 349  0.91381 -0.00884  0.80773 -0.12928  0.88729  0.01215  0.92155 -0.02320
# 350  0.85764 -0.04569  0.87170 -0.03515  0.81722 -0.09490  0.71002  0.04394
#
#        'a25'    'a26'    'a27'    'a28'    'a29'    'a30'    'a31'    'a32'  \
# 0    0.56811 -0.51171  0.41078 -0.46168  0.21266 -0.34090  0.42267 -0.54487
# 1   -0.20332 -0.26569 -0.20468 -0.18401 -0.19040 -0.11593 -0.16626 -0.06288
# 2    0.57528 -0.40220  0.58984 -0.22145  0.43100 -0.17365  0.60436 -0.24180
# 3    1.00000  0.90695  0.51613  1.00000  1.00000 -0.20099  0.25682  1.00000
# 4    0.03286 -0.65158  0.13290 -0.53206  0.02431 -0.62197 -0.05707 -0.59573
# ..       ...      ...      ...      ...      ...      ...      ...      ...
# 346  0.95378 -0.04202  0.83479  0.00123  1.00000  0.12815  0.86660 -0.10714
# 347  0.94520  0.01361  0.93522  0.04925  0.93159  0.08168  0.94066 -0.00035
# 348  0.93988  0.03193  0.92489  0.02542  0.92120  0.02242  0.92459  0.00442
# 349  0.91050 -0.02099  0.89147 -0.07760  0.82983 -0.17238  0.96022 -0.03757
# 350  0.86467 -0.15114  0.81147 -0.04822  0.78207 -0.00703  0.75747 -0.06678
#
#        'a33'    'a34'  'class'
# 0    0.18641 -0.45300        0
# 1   -0.13738 -0.02447        1
# 2    0.56045 -0.38238        0
# 3   -0.32382  1.00000        1
# 4   -0.04608 -0.65697        0
# ..       ...      ...      ...
# 346  0.90546 -0.04307        0
# 347  0.91483  0.04712        0
# 348  0.92697 -0.00577        0
# 349  0.87403 -0.16243        0
# 350  0.85764 -0.06151        0
#
# [351 rows x 36 columns]

# %% [markdown]
# KGFarm exploits the abstracted link between the KGLiDS graph and Farm graph
#    * <code> kgfarm.recommend_feature_transformations</code> returns all possible set of feature transformations that exists in the database.
#    * <b> You can pass your existing <code>entity_df</code> to <code>kgfarm.recommend_feature_transformations(entity:pd.Dataframe)</code> to look for possible feature transformations for that very entity dataframe.

# %%
transformation_info = kgfarm.recommend_feature_transformations(entity_df)
transformation_info
# Out:
# Processing unseen data
# • Insights about your entity_df:
# 1. 'a04' is a numeric column that looks like a categorical feature
# 2. 'a10' is a numeric column that looks like a categorical feature
# 3. 'a15' is a numeric column that looks like a categorical feature
#    Transformation        Package  Library                         Feature  \
# 0  OrdinalEncoder  preprocessing  sklearn  ['a04', 'a10', 'a15', 'class']
# 1  StandardScaler  preprocessing  sklearn                         ['a02']
# 2    RobustScaler  preprocessing  sklearn           ['a24', 'a30', 'a32']
#
#            Transformation_type
# 0             Ordinal encoding
# 1                      Scaling
# 2  Scaling concerning outliers

# %%
entity_df, transformation_model = kgfarm.apply_transformation(transformation_info.iloc[0],entity_df)
# Out:
# Applying OrdinalEncoder transformation
# 4 feature(s) ["'a04'", "'a10'", "'a15'", "'class'"] transformed successfully!
# final:  ['id', "'a01'", "'a02'", "'a03'", "'a04'", "'a05'", "'a06'", "'a07'", "'a08'", "'a09'", "'a10'", "'a11'", "'a12'", "'a13'", "'a14'", "'a15'", "'a16'", "'a17'", "'a18'", "'a19'", "'a20'", "'a21'", "'a22'", "'a23'", "'a24'", "'a25'", "'a26'", "'a27'", "'a28'", "'a29'", "'a30'", "'a31'", "'a32'", "'a33'", "'a34'", "'class'"]

# %%
entity_df, transformation_model = kgfarm.apply_transformation(transformation_info.iloc[2],entity_df)

# %%
entity_df

# %%
# entity_df['def'] = entity_df['def'].apply(lambda x: 1 if x == 'Y' else 0)
# entity_df.reset_index(drop=True, inplace=True)
# entity_df

# %%
entity_df, transformation_model = kgfarm.apply_transformation(transformation_info.iloc[1],entity_df)

# %%
X, y = kgfarm.select_features(entity_df, dependent_variable="'Class'",select_by='correlation')
X

# %%
dependent_variable = "'class'"
independent_variables = [feature for feature in list(entity_df.columns) if feature != dependent_variable]

X = entity_df[independent_variables]
y = entity_df[dependent_variable]

# %%
from sklearn.model_selection import cross_val_score, KFold, StratifiedKFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

rfc = RandomForestClassifier(n_estimators=10000)
lrc = LogisticRegression()

# %%
k_folds = StratifiedKFold(n_splits = 10, shuffle=True)

scores = cross_val_score(rfc, X, y, cv = k_folds, scoring='f1').mean()
print(scores)
scores1 = cross_val_score(rfc, X, y, cv = k_folds, scoring='precision').mean()
print(scores1)
scores2 = cross_val_score(rfc, X, y, cv = k_folds, scoring='recall').mean()
print(scores2)
scores = cross_val_score(rfc, X, y, cv = k_folds, scoring='f1').mean()
scores
# Out:
# 0.9502669328601006
# 0.9328491436100134
# 0.9691699604743083
# 0.950173340381481

# %%
entity_df
