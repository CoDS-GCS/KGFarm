# %% [markdown]
# ## KGFarm's feature transformation

# %%
import pandas as pd
df = pd.read_csv(r'C:\Users\niki_\Google Drive\GRAD SCHOOL\Papers\KGFarm-LFE\megawatt1.csv')

# %%
import os
import pandas as pd
os.chdir('../../')

from operations.api import KGFarm
kgfarm = KGFarm()
# Out:
# (KGFarm is running in Human in the loop mode)
# Connected to Stardog!
# Access the Stardog UI at: https://cloud.stardog.com/

# %%
df = kgfarm.clean_data(df,'fill')
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 8/8 [00:00<00:00, 182.70it/s]
# nothing to clean

# %% [markdown]
# KGFarm exploits the abstracted link between the KGLiDS graph and Farm graph
#    * <code> kgfarm.recommend_feature_transformations</code> returns all possible set of feature transformations that exists in the database.
#    * <b> You can pass your existing <code>entity_df</code> to <code>kgfarm.recommend_feature_transformations(entity:pd.Dataframe)</code> to look for possible feature transformations for that very entity dataframe.

# %%
transformation_info = kgfarm.recommend_feature_transformations(df)
transformation_info
# Out:
# Processing unseen entity_df
# 100%|██████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:00<00:00, 125.78it/s]
#    Transformation        Package  Library  \
# 0    LabelEncoder  preprocessing  sklearn
# 1  StandardScaler  preprocessing  sklearn
#
#                                                                Feature  \
# 0                                                                [def]
# 1  [am, ak, aj, ai, ag, af, ac, ab, id, u, s, p, m, k, f, c, a, an, z]
#
#             Transformation_type
# 0  Categorical feature encoding
# 1               Feature scaling

# %%
entity_df, transformation_model = kgfarm.apply_transformation(transformation_info.iloc[0],df)
# Out:
# Applying LabelEncoder transformation
# 100%|████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 1/1 [00:00<00:00, 499.68it/s]
# 1 feature(s) ['def'] transformed successfully!

# %%
entity_df, transformation_model = kgfarm.apply_transformation(transformation_info.iloc[1],df)
# Out:
# CAUTION: Make sure you apply StandardScaler transformation only on the train set (This ensures there is no over-fitting due to feature leakage)
# Use the transformation_model returned from this api to transform test set independently.
#
# Applying StandardScaler transformation
# 19 feature(s) ['am', 'ak', 'aj', 'ai', 'ag', 'af', 'ac', 'ab', 'id', 'u', 's', 'p', 'm', 'k', 'f', 'c', 'a', 'an', 'z'] transformed successfully!

# %%
X, y = kgfarm.select_features(entity_df, dependent_variable='def',select_by='correlation')
X
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 39/39 [00:03<00:00, 10.74it/s]
# Analyzing features
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [6], in <cell line: 1>()
# ----> 1 X, y = kgfarm.select_features(entity_df, dependent_variable='def',select_by='correlation')
#       2 X
#
# File ~\OneDrive\Documents\GitHub\KGFarm\operations\api.py:487, in KGFarm.select_features(self, entity_df, dependent_variable, select_by, plot_correlation, plot_anova_test, show_f_value)
#     485     table_ids = self.__table_transformations.get(tuple(entity_df.columns))
#     486     if table_ids is None:
# --> 487         return handle_data_by_statistics(dependent_var=y, f_score=feature_scores)
#     489 if select_by in {'anova', 'correlation'}:
#     490     return handle_data_by_statistics(dependent_var=y, f_score=feature_scores)
#
# File ~\OneDrive\Documents\GitHub\KGFarm\operations\api.py:427, in KGFarm.select_features.<locals>.handle_data_by_statistics(dependent_var, f_score)
#     425 elif select_by == 'correlation':
#     426     correlation = df.corr()
# --> 427     correlation.drop(index=dependent_variable, inplace=True)
#     428     columns = list(correlation.columns)
#     429     columns = [f for f in columns if f != dependent_variable]
#
# File c:\users\niki_\appdata\local\programs\python\python39\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File c:\users\niki_\appdata\local\programs\python\python39\lib\site-packages\pandas\core\frame.py:4948, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4800 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4801 def drop(
#    4802     self,
#    (...)
#    4809     errors: str = "raise",
#    4810 ):
#    4811     """
#    4812     Drop specified labels from rows or columns.
#    4813
#    (...)
#    4946             weight  1.0     0.8
#    4947     """
# -> 4948     return super().drop(
#    4949         labels=labels,
#    4950         axis=axis,
#    4951         index=index,
#    4952         columns=columns,
#    4953         level=level,
#    4954         inplace=inplace,
#    4955         errors=errors,
#    4956     )
#
# File c:\users\niki_\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py:4279, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4277 for axis, labels in axes.items():
#    4278     if labels is not None:
# -> 4279         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4281 if inplace:
#    4282     self._update_inplace(obj)
#
# File c:\users\niki_\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py:4323, in NDFrame._drop_axis(self, labels, axis, level, errors, consolidate, only_slice)
#    4321         new_axis = axis.drop(labels, level=level, errors=errors)
#    4322     else:
# -> 4323         new_axis = axis.drop(labels, errors=errors)
#    4324     indexer = axis.get_indexer(new_axis)
#    4326 # Case for non-unique axis
#    4327 else:
#
# File c:\users\niki_\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexes\base.py:6644, in Index.drop(self, labels, errors)
#    6642 if mask.any():
#    6643     if errors != "ignore":
# -> 6644         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6645     indexer = indexer[~mask]
#    6646 return self.delete(indexer)
#
# KeyError: "['def'] not found in axis"

# %%
dependent_variable = 'def'
independent_variables = [feature for feature in list(entity_df.columns) if feature != dependent_variable]

X = entity_df[independent_variables]
y = entity_df[dependent_variable]

# %%
from sklearn.model_selection import cross_val_score, KFold
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression

rfc = RandomForestClassifier(n_estimators=100)
lrc = LogisticRegression()

# %%
k_folds = KFold(n_splits = 10)

scores = cross_val_score(rfc, X, y, cv = 10, scoring='f1').mean()
scores
# Out:
# nan
